# %% [markdown]
# ## Voltando à tabela de salários
#
# A partir dos tópicos estudados de estatística descritiva, analise as variáveis do arquivo TabelaSalarial.csv.
#
# 1) Calcule as medidas de centralidade e dispersão das variáveis;
#
# 2) Plote histogramas de todas as variáveis;
#
# 3) Faça o boxplot de todas as variáveis.
#
# 4) Escreva uma análise de todas as variáveis, no formato texto corrido, com as informações que vocês geraram nos itens anteriores (Procurem escrever um texto como se estivessem apresentando as informações para uma pessoa leiga)
#
# O prazo final para entrega desta atividade é dia 21 de agosto, quarta-feira, às 23h59

# %%
#%pip install pandas seaborn matplotlib scipy statsmodels

# %%
import pandas as pd 
import seaborn as sn
import matplotlib.pyplot as plt 
import scipy 
import numpy as np
import statsmodels.api as sm 
from statsmodels.formula.api import ols

# %%
# leitura do arquivo
tabela = pd.read_csv('TabelaSalarial.csv')
tabela
# Out:
#      N Estado Civil   Grau de Instrução  N de Filhos  Salario (x Sal Min)  \
# 0    1     solteiro  ensino fundamental          NaN                 4.00
# 1    2       casado  ensino fundamental          1.0                 4.56
# 2    3       casado  ensino fundamental          2.0                 5.25
# 3    4     solteiro        ensino médio          NaN                 5.73
# 4    5     solteiro  ensino fundamental          NaN                 6.26
# 5    6       casado  ensino fundamental          0.0                 6.66
# 6    7     solteiro  ensino fundamental          NaN                 6.86
# 7    8     solteiro  ensino fundamental          NaN                 7.39
# 8    9       casado        ensino médio          1.0                 7.59
# 9   10     solteiro        ensino médio          NaN                 7.44
# 10  11       casado        ensino médio          2.0                 8.12
# 11  12     solteiro  ensino fundamental          NaN                 8.46
# 12  13     solteiro        ensino médio          NaN                 8.74
# 13  14       casado  ensino fundamental          3.0                 8.95
# 14  15       casado        ensino médio          0.0                 9.13
# 15  16     solteiro        ensino médio          NaN                 9.35
# 16  17       casado        ensino médio          1.0                 9.77
# 17  18       casado  ensino fundamental          2.0                 9.80
# 18  19     solteiro            superior          NaN                10.53
# 19  20     solteiro        ensino médio          NaN                10.76
# 20  21       casado        ensino médio          1.0                11.06
# 21  22     solteiro        ensino médio          NaN                11.59
# 22  23     solteiro  ensino fundamental          NaN                12.00
# 23  24       casado            superior          0.0                12.79
# 24  25       casado        ensino médio          2.0                13.23
# 25  26       casado        ensino médio          2.0                13.60
# 26  27     solteiro  ensino fundamental          NaN                13.85
# 27  28       casado        ensino médio          0.0                14.69
# 28  29       casado        ensino médio          5.0                14.71
# 29  30       casado        ensino médio          2.0                15.99
# 30  31     solteiro            superior          NaN                16.22
# 31  32       casado        ensino médio          1.0                16.61
# 32  33       casado            superior          3.0                17.26
# 33  34     solteiro            superior          NaN                18.75
# 34  35       casado        ensino médio          2.0                19.40
# 35  36       casado            superior          3.0                23.30
#
#     Idade (em anos) Região de Procedência
# 0                26              interior
# 1                32               capital
# 2                36               capital
# 3                20                 outra
# 4                40                 outra
# 5                28              interior
# 6                41              interior
# 7                43               capital
# 8                34               capital
# 9                23                 outra
# 10               33              interior
# 11               27               capital
# 12               37                 outra
# 13               44                 outra
# 14               30              interior
# 15               38                 outra
# 16               31               capital
# 17               39                 outra
# 18               25              interior
# 19               37              interior
# 20               30                 outra
# 21               34               capital
# 22               41                 outra
# 23               26                 outra
# 24               32              interior
# 25               35                 outra
# 26               46                 outra
# 27               29              interior
# 28               40              interior
# 29               35               capital
# 30               31                 outra
# 31               36              interior
# 32               43               capital
# 33               33               capital
# 34               48               capital
# 35               42              interior

# %%
# Entender o arquivo para manipular dados inconsistntes
tabela.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   N                      36 non-null     int64
#  1   Estado Civil           36 non-null     object
#  2   Grau de Instrução      36 non-null     object
#  3   N de Filhos            20 non-null     float64
#  4   Salario (x Sal Min)    36 non-null     float64
#  5   Idade (em anos)        36 non-null     int64
#  6   Região de Procedência  36 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 2.1+ KB

# %%
# Como os dados estão bem estruturados, vamos só preencher as células NaN com zero
tabela_clean = tabela.fillna(0)
tabela_clean
# Out:
#      N Estado Civil   Grau de Instrução  N de Filhos  Salario (x Sal Min)  \
# 0    1     solteiro  ensino fundamental          0.0                 4.00
# 1    2       casado  ensino fundamental          1.0                 4.56
# 2    3       casado  ensino fundamental          2.0                 5.25
# 3    4     solteiro        ensino médio          0.0                 5.73
# 4    5     solteiro  ensino fundamental          0.0                 6.26
# 5    6       casado  ensino fundamental          0.0                 6.66
# 6    7     solteiro  ensino fundamental          0.0                 6.86
# 7    8     solteiro  ensino fundamental          0.0                 7.39
# 8    9       casado        ensino médio          1.0                 7.59
# 9   10     solteiro        ensino médio          0.0                 7.44
# 10  11       casado        ensino médio          2.0                 8.12
# 11  12     solteiro  ensino fundamental          0.0                 8.46
# 12  13     solteiro        ensino médio          0.0                 8.74
# 13  14       casado  ensino fundamental          3.0                 8.95
# 14  15       casado        ensino médio          0.0                 9.13
# 15  16     solteiro        ensino médio          0.0                 9.35
# 16  17       casado        ensino médio          1.0                 9.77
# 17  18       casado  ensino fundamental          2.0                 9.80
# 18  19     solteiro            superior          0.0                10.53
# 19  20     solteiro        ensino médio          0.0                10.76
# 20  21       casado        ensino médio          1.0                11.06
# 21  22     solteiro        ensino médio          0.0                11.59
# 22  23     solteiro  ensino fundamental          0.0                12.00
# 23  24       casado            superior          0.0                12.79
# 24  25       casado        ensino médio          2.0                13.23
# 25  26       casado        ensino médio          2.0                13.60
# 26  27     solteiro  ensino fundamental          0.0                13.85
# 27  28       casado        ensino médio          0.0                14.69
# 28  29       casado        ensino médio          5.0                14.71
# 29  30       casado        ensino médio          2.0                15.99
# 30  31     solteiro            superior          0.0                16.22
# 31  32       casado        ensino médio          1.0                16.61
# 32  33       casado            superior          3.0                17.26
# 33  34     solteiro            superior          0.0                18.75
# 34  35       casado        ensino médio          2.0                19.40
# 35  36       casado            superior          3.0                23.30
#
#     Idade (em anos) Região de Procedência
# 0                26              interior
# 1                32               capital
# 2                36               capital
# 3                20                 outra
# 4                40                 outra
# 5                28              interior
# 6                41              interior
# 7                43               capital
# 8                34               capital
# 9                23                 outra
# 10               33              interior
# 11               27               capital
# 12               37                 outra
# 13               44                 outra
# 14               30              interior
# 15               38                 outra
# 16               31               capital
# 17               39                 outra
# 18               25              interior
# 19               37              interior
# 20               30                 outra
# 21               34               capital
# 22               41                 outra
# 23               26                 outra
# 24               32              interior
# 25               35                 outra
# 26               46                 outra
# 27               29              interior
# 28               40              interior
# 29               35               capital
# 30               31                 outra
# 31               36              interior
# 32               43               capital
# 33               33               capital
# 34               48               capital
# 35               42              interior

# %%
# Quais são os fatores que mais influenciam no salário?

tabela_numerica1 = tabela_clean.select_dtypes(include=[np.number])
tabela_numerica = tabela_numerica1.drop(columns=['N'])

# %%
pearson_correl = tabela_numerica.corr(method='pearson')
display(pearson_correl)
# Out:
#                      N de Filhos  Salario (x Sal Min)  Idade (em anos)
# N de Filhos             1.000000             0.375551         0.422981
# Salario (x Sal Min)     0.375551             1.000000         0.363362
# Idade (em anos)         0.422981             0.363362         1.000000

# %% [markdown]
# # Interpretação das correlações
#
# ###  0.00 a 0.02  : Muito Fraca
# ###  0.02 a 0.10  : Fraca
# ###  0.10 a 0.30  : Moderada
# ###  0.30 a 0.50  : Forte
# ###  0.50 a 1.00  : Muito Forte (Verifique os dados!)

# %%
# Análise 1- Idade e número de filhos
# Criar faixas de idade em intervalos de 5 anos

tabela_numerica['Faixa de Idade'] = pd.cut(tabela_numerica['Idade (em anos)'], bins=[20, 24, 29, 34, 39, 44, 49], 
                                           labels=['20-24', '25-29', '30-34', '35-39', '40-44', '45-49'])

# Ajustar o tamanho da figura
plt.figure(figsize=(5, 3))

# Criar o gráfico de barras com as faixas de idade
sn.barplot(data=tabela_numerica, x="Faixa de Idade", y="N de Filhos", errorbar=None, palette="viridis", estimator=np.mean)

# Adicionar rótulos e título
plt.xlabel("Faixa de Idade")
plt.ylabel("Média de Filhos")
plt.title("Média de Filhos por Faixa de Idade")

# Análise 2 - Salário e número de filhos
# Criar faixas de salário em intervalos de 1000 reais

tabela_numerica['Faixa de Salário'] = pd.cut(tabela_numerica['Salario (x Sal Min)'], 
                                             bins=[0, 6, 12, 18, 24])

# Ajustar o tamanho da figura
plt.figure(figsize=(5, 3))

# Criar o gráfico de barras com as faixas de salário
sn.barplot(data=tabela_numerica, x="Faixa de Salário", y="Salario (x Sal Min)", errorbar=None, palette="viridis")

# Adicionar rótulos e título
plt.xlabel("Faixa de Salário")
plt.ylabel("Média de Salário (x Sal Min)")

# Análise 3 - Salário e idade

# Ajustar o tamanho da figura
plt.figure(figsize=(5, 3))

# Criar o gráfico de dispersão com a idade e o salário

# Criar o gráfico de dispersão
sn.scatterplot(data=tabela_numerica, x="Idade (em anos)", y="Salario (x Sal Min)")

# Calcular a linha de tendência
x = tabela_numerica["Idade (em anos)"]
y = tabela_numerica["Salario (x Sal Min)"]
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='red')

# Adicionar rótulos e título
plt.xlabel("Idade")
plt.ylabel("Salário")
figsize=(5, 3)

# Ajustar layout
plt.tight_layout()

# Mostrar o gráfico
plt.show()
# Out:
# C:\Users\gafeb\AppData\Local\Temp\ipykernel_12808\1171207781.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.barplot(data=tabela_numerica, x="Faixa de Idade", y="N de Filhos", errorbar=None, palette="viridis", estimator=np.mean)
# C:\Users\gafeb\AppData\Local\Temp\ipykernel_12808\1171207781.py:28: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.barplot(data=tabela_numerica, x="Faixa de Salário", y="Salario (x Sal Min)", errorbar=None, palette="viridis")

# %% [markdown]
# #### Os gráficos confirmam a tendência mostrada pelas correlações estatísticas

# %%
# Convertendo variáveis qualitativas para variáveis dummy
tabela_clean_dummies = pd.get_dummies(tabela_clean, columns=['Grau de Instrução', 'Região de Procedência'], drop_first=True)
tabela_clean_dummies['Estado Civil'] = tabela_clean_dummies['Estado Civil'].map({'solteiro': 0, 'casado': 1})

# Renomear colunas para remover espaços e caracteres especiais
tabela_clean_dummies.columns = tabela_clean_dummies.columns.str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# Variáveis numéricas
numeric_vars = ['Idade_em_anos', 'Salario_x_Sal_Min', 'N_de_Filhos']

# Agrupando variáveis qualitativas dummy
qualitative_groups = {
    'Estado_Civil': ['Estado_Civil'],
    'Grau_de_Instrução': [col for col in tabela_clean_dummies.columns if 'Grau_de_Instrução' in col],
    'Região_de_Procedência': [col for col in tabela_clean_dummies.columns if 'Região_de_Procedência' in col]
}

# Função para calcular o R^2
def calculate_r_squared(dependent_var, independent_vars):
    formula = f"{dependent_var} ~ " + " + ".join(independent_vars)
    model = ols(formula, data=tabela_clean_dummies).fit()
    return model.rsquared

# Criar a tabela de R^2
r_squared_table = pd.DataFrame(index=numeric_vars, columns=qualitative_groups.keys())

for numeric_var in numeric_vars:
    for qual_group, qual_vars in qualitative_groups.items():
        r_squared = calculate_r_squared(numeric_var, qual_vars)
        r_squared_table.loc[numeric_var, qual_group] = r_squared

display(r_squared_table)
# Out:
#                   Estado_Civil Grau_de_Instrução Região_de_Procedência
# Idade_em_anos         0.009095          0.061719              0.027332
# Salario_x_Sal_Min      0.06125          0.413297              0.012725
# N_de_Filhos           0.442009          0.020802              0.033741

# %% [markdown]
# # Interpretação dos valores de R^2
# #
# ###  0   a 0.1   : Muito Fraca
# ###  0.1 a 0.3   : Fraca
# ###  0.3 a 0.7   : Moderada
# ###  0.7 a 1.0   : Forte

# %%
# Fazendo as análises por histogramas das variáveis que aprenstam as melhores correlações:
# 1- Número de filhos com estado civil
# 2- Salário com Grau de instrução

# histograma do número de filhos por estado civil
plt.figure(figsize=(5, 3))
sn.histplot(data=tabela_clean_dummies, x='N_de_Filhos', hue='Estado_Civil', palette='viridis', multiple='stack')
plt.xlabel('Número de Filhos')
plt.ylabel('Contagem')



# Ajustar layout
plt.tight_layout()

# Mostrar os gráficos
plt.show()

# %%
tabela_clean
# Out:
#      N Estado Civil   Grau de Instrução  N de Filhos  Salario (x Sal Min)  \
# 0    1     solteiro  ensino fundamental          0.0                 4.00
# 1    2       casado  ensino fundamental          1.0                 4.56
# 2    3       casado  ensino fundamental          2.0                 5.25
# 3    4     solteiro        ensino médio          0.0                 5.73
# 4    5     solteiro  ensino fundamental          0.0                 6.26
# 5    6       casado  ensino fundamental          0.0                 6.66
# 6    7     solteiro  ensino fundamental          0.0                 6.86
# 7    8     solteiro  ensino fundamental          0.0                 7.39
# 8    9       casado        ensino médio          1.0                 7.59
# 9   10     solteiro        ensino médio          0.0                 7.44
# 10  11       casado        ensino médio          2.0                 8.12
# 11  12     solteiro  ensino fundamental          0.0                 8.46
# 12  13     solteiro        ensino médio          0.0                 8.74
# 13  14       casado  ensino fundamental          3.0                 8.95
# 14  15       casado        ensino médio          0.0                 9.13
# 15  16     solteiro        ensino médio          0.0                 9.35
# 16  17       casado        ensino médio          1.0                 9.77
# 17  18       casado  ensino fundamental          2.0                 9.80
# 18  19     solteiro            superior          0.0                10.53
# 19  20     solteiro        ensino médio          0.0                10.76
# 20  21       casado        ensino médio          1.0                11.06
# 21  22     solteiro        ensino médio          0.0                11.59
# 22  23     solteiro  ensino fundamental          0.0                12.00
# 23  24       casado            superior          0.0                12.79
# 24  25       casado        ensino médio          2.0                13.23
# 25  26       casado        ensino médio          2.0                13.60
# 26  27     solteiro  ensino fundamental          0.0                13.85
# 27  28       casado        ensino médio          0.0                14.69
# 28  29       casado        ensino médio          5.0                14.71
# 29  30       casado        ensino médio          2.0                15.99
# 30  31     solteiro            superior          0.0                16.22
# 31  32       casado        ensino médio          1.0                16.61
# 32  33       casado            superior          3.0                17.26
# 33  34     solteiro            superior          0.0                18.75
# 34  35       casado        ensino médio          2.0                19.40
# 35  36       casado            superior          3.0                23.30
#
#     Idade (em anos) Região de Procedência
# 0                26              interior
# 1                32               capital
# 2                36               capital
# 3                20                 outra
# 4                40                 outra
# 5                28              interior
# 6                41              interior
# 7                43               capital
# 8                34               capital
# 9                23                 outra
# 10               33              interior
# 11               27               capital
# 12               37                 outra
# 13               44                 outra
# 14               30              interior
# 15               38                 outra
# 16               31               capital
# 17               39                 outra
# 18               25              interior
# 19               37              interior
# 20               30                 outra
# 21               34               capital
# 22               41                 outra
# 23               26                 outra
# 24               32              interior
# 25               35                 outra
# 26               46                 outra
# 27               29              interior
# 28               40              interior
# 29               35               capital
# 30               31                 outra
# 31               36              interior
# 32               43               capital
# 33               33               capital
# 34               48               capital
# 35               42              interior

# %%
# 2- Salário com Grau de instrução

# histograma do número de filhos por estado civil
plt.figure(figsize=(5, 3))
sn.barplot(data=tabela_clean, x='Grau de Instrução', y='Salario (x Sal Min)', palette='viridis', estimator=np.mean)
plt.xlabel('Grau de Instrução')
plt.ylabel('Salário (x Sal Min)')
plt.title(' ')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\gafeb\AppData\Local\Temp\ipykernel_12808\738056267.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.barplot(data=tabela_clean, x='Grau de Instrução', y='Salario (x Sal Min)', palette='viridis', estimator=np.mean)
